# %% [markdown]
# <a href="https://colab.research.google.com/github/HwangHanJae/ml-definitive-guide-pratice/blob/main/regression/understanding_simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 단순 선형 회귀를 통한 회귀 이해
# <h3> :  독립변수도 하나, 종속 변수도 하나인 선형 회귀</h3>
#
# 주택 가격이 주택의 크기로만 결정된다고 가정한다면
# - 일반적으로 주택의 크기가 크면 가격이 높아지는 경향이 있음
#
# 다음과 같이 주택 가격은 주택 크기에 대해 선형(직선 형태)의 관계로 표현할 수 있음
#
# ![image.png](data:image/png;base64,...)
#
# X축이 주택의 크기 축이고 Y축이 주택의 가격축인 2차원 평면에서 주택 가격은 특정기울기와 절편을 가진 1차 함수식으로 모델링을 할 수 있음
#
# 즉 $Y = w_0 + w_1 * X$로 계산할 수 있음
#
# - 독립변수가 1개인 단순 선형 회귀에서는 기울기 $w_0$과 절편 $w_1$을 회귀 계수로 지칭
#
# ![image.png](data:image/png;base64,...)
#
# 회귀 모델은 이러한 $Y = w_0+w_1*X$와 같은 1차 함수로 모델링 했다면 실제 주택 가격은 이러한 1차 함수 값에서 실제 값만큼의 오류값을 빼거나 더한 값이 됨
#
# 실제값과 회귀 모델의 차이에 따른 오류 값을 남은 오류 **즉 잔차**라고 함
# **최적의 회귀 모델을 만든다는 것은 바로 전체 데이터의 잔차(오류 값)합이 최소가 되는 모델을 만든다는 의미**
# - 동시에 오류 값 합이 최소가 될 수 있는 최적의 회귀 계수를 찾는다는 의미
#
# 오류값은 $+ or -$값이 될 수 있음
# 보통 오류 합을 계산할때는 절댓값을 취해서 더하거나($Mean Absolute Error$)
# 오류 값의 제곱을 구해서 더하는 방식($RSS, Residual Sum of Square$)을 취함
#
# 일반적으로는 RSS방식으로 오류합을 구함
# $$Error^2 = RSS$$
#
# ![image.png](data:image/png;base64,...)
#
# RSS는 $w_0, w_1$인 식으로 표현할 수 있음
# - RSS를 최소로하는 $w_0, w_1$ 즉 회귀 계수를 학습을 통해서 찾는 것이 머신러닝 기반 회귀의 핵심 사항
#
# RSS는 회귀식의 독립변수 X, 종속변수 Y가 아니라 w 변수가 중심 변수임을 인지해야함
# (학습 데이터로 입력되는 독립변수와 종속변수는 RSS에서 모두 상수로 간주)
#
# 일반적으로 RSS는 학습 데이터의 건수로 나누어서 다음과 같은 정규화된 식으로 표현
#
# $$RSS(w_0,w_1) = \frac{1}{N}\sum_{i=1}^{N}(y_i - (w_0+w_1*x_i))^2$$
#
# **회귀에서 이 RSS는 비용(Cost)이며 w 변수(회귀 계수)로 구성되는 RSS를 비용함수라고 함**
#
# **머신러닝 회귀 알고리즘은 데이터를 계속 학습하면서 이 비용함수가 반환되는 값(즉 오류값)을 지속해서 감소시키고 최종적으로는 더 이상 감소하지 않는 최소의 오류값을 구함**
#
# **비용함수를 손실함수(loss function)이라고 함**
